# %%
#To perform NaiveBayes and K-NN (K-Nearest neighbor) classification technique using sci-kit learn.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score as score
from sklearn.preprocessing import StandardScaler

# %%
d = load_breast_cancer()

# %%
X = d.data
y = d.target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(X_test)

plt.scatter(y_test,y_predict)
plt.show()

# %%
print(score(y_predict,y_test))
# Out:
# 0.9370629370629371

# %%
#knn on placement and detail's data set

# %%
d = pd.read_csv("Details.csv")
d1 = pd.read_csv("Placement.csv")

# %%
print(d,d1)
# Out:
#     Roll No.  Age  Weight Branch  Gender  SSC Result  HSC Result  \
# 0        201   21      78    MBA    Male       86.16       93.60
# 1        202   21      72    MBA    Male       95.50       86.92
# 2        203   21      80    MBA    Male       92.50       88.46
# 3        204   20      75    BCA    Male       82.66       75.38
# 4        205   20      61    BCA  Female       91.00       79.07
# 5        206   21      78    MBA    Male       91.00       74.46
# 6        207   21      72    BCA    Male       89.00       79.53
# 7        208   22      80    MBA    Male       78.83       78.15
# 8        209   22      75    BCA    Male       93.67       81.23
# 9        210   21      80    MBA    Male       93.00       83.53
# 10       211   20      78    MBA    Male       80.83       82.61
# 11       212   20      72    MBA    Male       93.66       79.53
# 12       213   22      80    MBA    Male       81.67       78.16
# ...

# %%
d['Sem 1'] = d['Sem 1'].fillna(0)
d["Sem 2"] = d["Sem 2"].fillna(0)
d["Sem 3"] = d["Sem 3"].fillna(0)
d["Sem 4"] = d["Sem 4"].fillna(0)
d["Sem 5"] = d["Sem 5"].fillna(0)
d["Sem 6"] = d["Sem 6"].fillna(0)



# print(d.columns)


d
# Out:
#     Roll No.  Age  Weight Branch  Gender  SSC Result  HSC Result  \
# 0        201   21      78    MBA    Male       86.16       93.60
# 1        202   21      72    MBA    Male       95.50       86.92
# 2        203   21      80    MBA    Male       92.50       88.46
# 3        204   20      75    BCA    Male       82.66       75.38
# 4        205   20      61    BCA  Female       91.00       79.07
# 5        206   21      78    MBA    Male       91.00       74.46
# 6        207   21      72    BCA    Male       89.00       79.53
# 7        208   22      80    MBA    Male       78.83       78.15
# 8        209   22      75    BCA    Male       93.67       81.23
# 9        210   21      80    MBA    Male       93.00       83.53
# 10       211   20      78    MBA    Male       80.83       82.61
# 11       212   20      72    MBA    Male       93.66       79.53
# 12       213   22      80    MBA    Male       81.67       78.16
# ...

# %%
d["Avg SPI"] = d["Avg SPI"].fillna((d["Sem 1"] + d["Sem 2"] + d["Sem 3"] + d["Sem 4"] + d["Sem 5"] + d["Sem 6"])/6)

d["CPI"] = d["CPI"].fillna((d["Sem 3"] + d["Sem 4"] + d["Sem 5"] + d["Sem 6"])/4)

print(d)
# Out:
#     Roll No.  Age  Weight Branch  Gender  SSC Result  HSC Result  \
# 0        201   21      78    MBA    Male       86.16       93.60
# 1        202   21      72    MBA    Male       95.50       86.92
# 2        203   21      80    MBA    Male       92.50       88.46
# 3        204   20      75    BCA    Male       82.66       75.38
# 4        205   20      61    BCA  Female       91.00       79.07
# 5        206   21      78    MBA    Male       91.00       74.46
# 6        207   21      72    BCA    Male       89.00       79.53
# 7        208   22      80    MBA    Male       78.83       78.15
# 8        209   22      75    BCA    Male       93.67       81.23
# 9        210   21      80    MBA    Male       93.00       83.53
# 10       211   20      78    MBA    Male       80.83       82.61
# 11       212   20      72    MBA    Male       93.66       79.53
# 12       213   22      80    MBA    Male       81.67       78.16
# ...

# %%
d = d[["CPI","Avg SPI"]]
d1 = d1["Placed"]

x = d
y = d1

# print(d.columns)

#whole data set have been converted to only CPI , Avg Spi and Placed and other params have been removed

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=0)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
y_predict1 = knn.predict([[0,0]])
print(y_predict1)
# Out:
# /lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ['Yes']

# %%
y_predict2 = knn.predict([[7.99,9]])
print(y_predict2)
# Out:
# /lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ['Yes']

# %%
plt.plot(y_test,y_predict)

print(score(y_test,y_predict))
# Out:
# 0.8888888888888888
